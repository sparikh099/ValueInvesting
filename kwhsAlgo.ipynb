# %%
import json
import csv
from io import StringIO
from bs4 import BeautifulSoup
import requests
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import mplfinance as mpf
import pandas_datareader as pdr
from matplotlib import rcParams
from matplotlib.patches import Rectangle
from json import JSONEncoder
import yfinance as yf

# %%
strategy = pd.read_excel('Long Term Analysis/WGYP-Investment-Competition-Stock-List-Industries.xlsx')
strategy
# Out:
#                                                  Stock  Ticker  \
# 0                     Air Products and Chemicals, Inc.     APD
# 1    Aluminum Corporation of China Limited ADR Class H     ACH
# 2                        Ashland Global Holdings, Inc.     ASH
# 3                                         Atul Limited  500027
# 4                                        BHP Group Plc     BHP
# ..                                                 ...     ...
# 508                                            SSE plc     SSE
# 509                         Tata Power Company Limited  500400
# 510                             The York Water Company    YORW
# 511                                    UGI Corporation     UGI
# 512                         United Utilities Group PLC     UU.
#
#                           Exchange         Industry      Supersector  \
# 0    New York Stock Exchange, Inc.  Basic Materials        Chemicals
# ...

# %%
stock_list = []
stock_industry = []
stock_sector = []
tickerPrice = []
for x in range(len(strategy)):
    stock_list.append(strategy['Ticker'][x])
    stock_industry.append(strategy['Industry'][x])
    stock_sector.append(strategy['Sector'][x])
print(stock_list)
# Out:
# ['APD', 'ACH', 'ASH', '500027', 'BHP', 'BRKM5', 'CHNR', 'CLW', 'CSNA3', 'EMN', 'FMC', 'FCX', 'FFHL', 'GGBR4', 'GLEN', '500440', 'IOSP', 'JMAT', 'KALU', 'KL', 'KLBN11', 'MMAT', 'NP', 'NTIC', 'PKX', 'KWR', 'ROLL', 'RIO', 'RGLD', 'SUZB3', '500470', 'X', 'VALE3', '500295', 'ANF', 'ATVI', 'AC', 'BABA', 'ATD.B', 'AMZN', 'AMC', 'AAL', 'AEO', 'APTV', 'AZO', 'AVP', '532977', 'BNED', '500043', 'BBBY', 'BBY', 'BWA', '500530', 'BYD', 'BBW', 'BURL', 'CZR', 'GOOS', 'KMX', 'CCL', 'CAKE', 'CAAS', 'CEA', 'ZNH', '601888', 'CMG', 'CPG', 'COST', 'DJCO', 'DAL', 'DG', 'DLTR', 'DOL', 'DOM', 'DPZ', 'EZJ', 'EDR', 'ETSY', 'FL', 'F', 'GPS', 'GM', 'HRB', 'HOG', 'HAS', '500182', 'HIBB', 'HD', 'HMC', 'HSW', 'H', 'IMAX', 'IHG', 'JBLU', '533155', 'LE', 'LVS', 'LCII', 'RENT3', 'LAME4', 'LREN3', 'LOOK', 'LULU', 'LYFT', 'M', 'MGLU3', '500520', 'MAR', '532500', 'MAT', 'MCD', '000333', 'MOV', 'NTES', 'NFLX', 'EDU', 'NXT', 'NKE', 'NCLH', 'OTB', 'ORLY', 'PZZA', 'PSON', 'PTON', 'PLNT', 'QSR', 'REV', 'RBA', 'SIRI', 'SKYW', 
# ...

# %%
yf.Ticker(stock_list[0]).financials
# Out:
#                                         2020-09-30  2019-09-30  2018-09-30  \
# Research Development                      8.39e+07    7.29e+07    6.45e+07
# Effect Of Accounting Charges                  None        None        None
# Income Before Tax                       2.4238e+09  2.2895e+09   2.015e+09
# Minority Interest                        3.633e+08   3.347e+08   3.188e+08
# Net Income                              1.8867e+09    1.76e+09  1.4978e+09
# Selling General Administrative            7.31e+08   7.297e+08   8.012e+08
# Gross Profit                            2.9982e+09  2.9434e+09  2.7407e+09
# Ebit                                    2.2472e+09  2.2199e+09  1.9252e+09
# Operating Income                        2.2472e+09  2.2199e+09  1.9252e+09
# Other Operating Expenses                 -6.39e+07   -7.91e+07   -5.02e+07
# Interest Expense                        -1.093e+08   -1.37e+08  -1.305e+08
# ...

# %%
#for y in range()
priceAnalysis = yf.Ticker(stock_list[0])

# %%
df = pd.DataFrame()
df['Ticker'] = stock_list
df['Price'] = 
df
# Out:
#      Ticker
# 0       APD
# 1       ACH
# 2       ASH
# 3    500027
# 4       BHP
# ..      ...
# 508     SSE
# 509  500400
# 510    YORW
# 511     UGI
# 512     UU.
#
# [513 rows x 1 columns]
